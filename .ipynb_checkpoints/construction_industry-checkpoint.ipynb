# %% [markdown]
# # Cтроительная отрасль в России и мире

# %% [markdown]
# ## Исследование условий ведения бизнеса Doing Business

# %% [markdown]
# https://archive.doingbusiness.org/ru/data/exploretopics/dealing-with-construction-permits

# %%
import pandas as pd

# %%
construction = pd.read_excel('/Users/yuliabezginova/PycharmProjects/real_estate_2022/Получение разрешений на строительство.xlsx')

# %%
construction.head(10)
# Out:
#   Unnamed: 0                                 Страна  \
# 0     Регион                                    NaN
# 1        NaN               Африка (к югу от Сахары)
# 2        NaN       Ближний Восток и Северная Африка
# 3        NaN  Восточная Азия и Тихоокеанский регион
# 4        NaN              Европа и Центральная Азия
# 5        NaN  Латинская Америка и Карибский бассейн
# 6        NaN                                   ОЭСР
# 7        NaN                             Южная Азия
# 8     Страна                                    NaN
# 9        NaN                               Камбоджа
#
#    Получение разрешений на строительство ПР  Процедуры (количество)  \
# 0                                       NaN                     NaN
# 1                                      58.5                    15.1
# 2                                      61.7                    15.7
# 3                                      70.0                    14.8
# 4                                      69.0                    16.2
# 5                                      63.2                    15.5
# 6                                      75.6                    12.7
# 7                                      65.3                    14.6
# 8                                       NaN                     NaN
# 9                                      44.6                    20.0
#
#    Срок (в днях)  Стоимость (% от стоимости товарного склада)  \
# 0            NaN                                          NaN
# 1          145.4                                          8.9
# 2          123.6                                          4.4
# 3          132.3                                          3.2
# 4          170.1                                          4.0
# 5          191.2                                          3.6
# 6          152.3                                          1.5
# 7          149.7                                         12.5
# 8            NaN                                          NaN
# 9          652.0                                          3.0
#
#    Индекс качества контроля в строительстве (0-15)  \
# 0                                              NaN
# 1                                              8.9
# 2                                             12.5
# 3                                              9.4
# 4                                             12.1
# 5                                              9.0
# 6                                             11.6
# 7                                              9.4
# 8                                              NaN
# 9                                              8.0
#
#   Получение разрешений на строительство pейтинг
# 0                                           NaN
# 1                                           126
# 2                                            87
# 3                                            84
# 4                                            85
# 5                                           117
# 6                                            52
# 7                                            98
# 8                                           NaN
# 9                                           178

# %%
construction = construction.iloc[9:, 0:].reset_index()
construction
# Out:
#      index Unnamed: 0                                Страна  \
# 0        9        NaN                              Камбоджа
# 1       10        NaN                                  Кипр
# 2       11        NaN  Венесуэла, Боливарианская Республика
# 3       12        NaN                  Бразилия - Сан-Паулу
# 4       13        NaN                              Барбадос
# ..     ...        ...                                   ...
# 208    217        NaN                  Йеменская Республика
# 209    218        NaN                                 Ливия
# 210    219        NaN         Сирийская Арабская Республика
# 211    220        NaN                                Сомали
# 212    221        NaN                               Эритрея
#
#      Получение разрешений на строительство ПР  Процедуры (количество)  \
# 0                                        44.6                    20.0
# 1                                        64.2                     8.0
# 2                                        46.5                    11.0
# 3                                        47.7                    19.0
# 4                                        56.6                     9.0
# ..                                        ...                     ...
# 208                                       0.0                 -9999.0
# 209                                       0.0                 -9999.0
# 210                                       0.0                 -9999.0
# 211                                       0.0                 -9999.0
# 212                                       0.0                 -9999.0
#
#      Срок (в днях)  Стоимость (% от стоимости товарного склада)  \
# 0            652.0                                          3.0
# 1            507.0                                          0.9
# 2            434.0                                         12.0
# 3            384.0                                          1.3
# 4            377.0                                          0.2
# ..             ...                                          ...
# 208        -9999.0                                      -9999.0
# 209        -9999.0                                      -9999.0
# 210        -9999.0                                      -9999.0
# 211        -9999.0                                      -9999.0
# 212        -9999.0                                      -9999.0
#
#      Индекс качества контроля в строительстве (0-15)  \
# 0                                                8.0
# 1                                               11.0
# 2                                               10.5
# 3                                                8.0
# 4                                                6.5
# ..                                               ...
# 208                                          -9999.0
# 209                                          -9999.0
# 210                                          -9999.0
# 211                                          -9999.0
# 212                                          -9999.0
#
#     Получение разрешений на строительство pейтинг
# 0                                             178
# 1                                             125
# 2                                             175
# 3                                              ..
# 4                                             153
# ..                                            ...
# 208                                           186
# 209                                           186
# 210                                           186
# 211                                           186
# 212                                           186
#
# [213 rows x 9 columns]

# %%
construction = construction.iloc[:, 2:]
construction
# Out:
#                                    Страна  \
# 0                                Камбоджа
# 1                                    Кипр
# 2    Венесуэла, Боливарианская Республика
# 3                    Бразилия - Сан-Паулу
# 4                                Барбадос
# ..                                    ...
# 208                  Йеменская Республика
# 209                                 Ливия
# 210         Сирийская Арабская Республика
# 211                                Сомали
# 212                               Эритрея
#
#      Получение разрешений на строительство ПР  Процедуры (количество)  \
# 0                                        44.6                    20.0
# 1                                        64.2                     8.0
# 2                                        46.5                    11.0
# 3                                        47.7                    19.0
# 4                                        56.6                     9.0
# ..                                        ...                     ...
# 208                                       0.0                 -9999.0
# 209                                       0.0                 -9999.0
# 210                                       0.0                 -9999.0
# 211                                       0.0                 -9999.0
# 212                                       0.0                 -9999.0
#
#      Срок (в днях)  Стоимость (% от стоимости товарного склада)  \
# 0            652.0                                          3.0
# 1            507.0                                          0.9
# 2            434.0                                         12.0
# 3            384.0                                          1.3
# 4            377.0                                          0.2
# ..             ...                                          ...
# 208        -9999.0                                      -9999.0
# 209        -9999.0                                      -9999.0
# 210        -9999.0                                      -9999.0
# 211        -9999.0                                      -9999.0
# 212        -9999.0                                      -9999.0
#
#      Индекс качества контроля в строительстве (0-15)  \
# 0                                                8.0
# 1                                               11.0
# 2                                               10.5
# 3                                                8.0
# 4                                                6.5
# ..                                               ...
# 208                                          -9999.0
# 209                                          -9999.0
# 210                                          -9999.0
# 211                                          -9999.0
# 212                                          -9999.0
#
#     Получение разрешений на строительство pейтинг
# 0                                             178
# 1                                             125
# 2                                             175
# 3                                              ..
# 4                                             153
# ..                                            ...
# 208                                           186
# 209                                           186
# 210                                           186
# 211                                           186
# 212                                           186
#
# [213 rows x 7 columns]

# %%
construction.columns
# Out:
# Index(['Страна', 'Получение разрешений на строительство ПР',
#        'Процедуры (количество)', 'Срок (в днях)',
#        'Стоимость (% от стоимости товарного склада)',
#        'Индекс качества контроля в строительстве (0-15)',
#        'Получение разрешений на строительство pейтинг'],
#       dtype='object')

# %%
construction = construction.rename(columns={
'Страна': 'country', 
    'Получение разрешений на строительство ПР': 'building_permit',
    'Процедуры (количество)': 'procedures', 
    'Срок (в днях)': 'days',
       'Стоимость (% от стоимости товарного склада)': 'cost',
       'Индекс качества контроля в строительстве (0-15)': 'qa_index',
       'Получение разрешений на строительство pейтинг': 'permit_raiting'
})
construction
# Out:
#                                   country  building_permit  procedures  \
# 0                                Камбоджа             44.6        20.0
# 1                                    Кипр             64.2         8.0
# 2    Венесуэла, Боливарианская Республика             46.5        11.0
# 3                    Бразилия - Сан-Паулу             47.7        19.0
# 4                                Барбадос             56.6         9.0
# ..                                    ...              ...         ...
# 208                  Йеменская Республика              0.0     -9999.0
# 209                                 Ливия              0.0     -9999.0
# 210         Сирийская Арабская Республика              0.0     -9999.0
# 211                                Сомали              0.0     -9999.0
# 212                               Эритрея              0.0     -9999.0
#
#        days    cost  qa_index permit_raiting
# 0     652.0     3.0       8.0            178
# 1     507.0     0.9      11.0            125
# 2     434.0    12.0      10.5            175
# 3     384.0     1.3       8.0             ..
# 4     377.0     0.2       6.5            153
# ..      ...     ...       ...            ...
# 208 -9999.0 -9999.0   -9999.0            186
# 209 -9999.0 -9999.0   -9999.0            186
# 210 -9999.0 -9999.0   -9999.0            186
# 211 -9999.0 -9999.0   -9999.0            186
# 212 -9999.0 -9999.0   -9999.0            186
#
# [213 rows x 7 columns]

# %%
filtered = construction[construction['days'] != -9999.0].sort_values(by='days', ascending=False)
filtered.head(11)
# Out:
#                                  country  building_permit  procedures   days  \
# 0                               Камбоджа             44.6        20.0  652.0
# 1                                   Кипр             64.2         8.0  507.0
# 2   Венесуэла, Боливарианская Республика             46.5        11.0  434.0
# 3                   Бразилия - Сан-Паулу             47.7        19.0  384.0
# 4                               Барбадос             56.6         9.0  377.0
# 5                               Бразилия             51.9        19.0  338.0
# 6                                Албания             52.7        19.0  324.0
# 7                              Аргентина             56.4        17.0  318.0
# 8                          Эль-Сальвадор             52.3        16.0  310.0
# 9                               Словакия             59.4        14.0  300.0
# 10                     Бангладеш - Дакка             60.3        16.0  281.0
#
#     cost  qa_index permit_raiting
# 0    3.0       8.0            178
# 1    0.9      11.0            125
# 2   12.0      10.5            175
# 3    1.3       8.0             ..
# 4    0.2       6.5            153
# 5    1.1       8.4            170
# 6    6.8      13.0            166
# 7    3.1      11.0            155
# 8    6.3      10.0            168
# 9    0.2       8.0            146
# 10   1.6      10.0             ..

# %%
filtered.tail(10)
# Out:
#                 country  building_permit  procedures  days  cost  qa_index  \
# 198           Финляндия             75.9        17.0  65.0   0.7      10.0
# 199               Дания             87.9         7.0  64.0   0.6      11.0
# 200              Грузия             81.0        11.0  63.0   0.3       9.0
# 201             Марокко             83.2        12.0  58.0   3.3      13.0
# 202               Самоа             68.8        18.0  57.0   0.8       6.0
# 203            Малайзия             89.0         9.0  53.0   1.3      13.0
# 204                 ОАЭ             89.8        11.0  47.5   2.2      15.0
# 205  Маршалловы Острова             71.1         7.0  38.0   2.2       1.0
# 206            Сингапур             87.9         9.0  35.5   3.3      13.0
# 207    Республика Корея             84.4        10.0  27.5   4.4      12.0
#
#     permit_raiting
# 198             42
# 199              4
# 200             21
# 201             16
# 202             94
# 203              2
# 204              3
# 205             76
# 206              5
# 207             12

# %%
filtered['days'].describe()
# Out:
# count    208.000000
# mean     153.944712
# std       80.550615
# min       27.500000
# 25%      101.750000
# 50%      137.000000
# 75%      184.250000
# max      652.000000
# Name: days, dtype: float64

# %%
russia = construction[(construction['country'] == 'Российская Федерация') | (construction['country'] == 'Российская Федерация - Санкт-Петербург') | (construction['country'] == 'Российская Федерация - Москва')]

# %%
russia
# Out:
#                                    country  building_permit  procedures  \
# 62  Российская Федерация - Санкт-Петербург             80.5        11.0
# 70                    Российская Федерация             78.9        13.0
# 76           Российская Федерация - Москва             78.2        14.0
#
#      days  cost  qa_index permit_raiting
# 62  175.0   0.9      14.0             ..
# 70  165.0   1.1      14.0             26
# 76  160.0   1.2      14.0             ..

# %%
construction['days'].median()
# Out:
# 134.0

# %%
near_russia = construction[(construction['days'] <= 180) & (construction['days'] >= 160 ) & (construction['days'] != -9999.0)]

# %%
len(near_russia)
# Out:
# 23

# %%
near_russia
# Out:
#                                    country  building_permit  procedures  \
# 56                       Багамские Острова             70.9        17.0
# 57                                  Греция             69.5        17.0
# 58                    Босния и Герцеговина             48.6        17.0
# 59                                  Мальта             73.5        16.0
# 60                                Зимбабве             60.0        10.0
# 61                                 Сенегал             62.1        14.0
# 62  Российская Федерация - Санкт-Петербург             80.5        11.0
# 63                                  Египет             71.2        20.0
# 64                                  Гамбия             59.4        12.0
# 65                                    Гана             67.6        16.0
# 66                                    Того             64.1        12.0
# 67                              Кыргызстан             69.0        17.0
# 68                                    Ирак             67.7        11.0
# 69                                 Вьетнам             79.3        10.0
# 70                    Российская Федерация             78.9        13.0
# 71                             Пуэрто-Рико             59.6        22.0
# 72                                Ирландия             76.6        10.0
# 73                        Республика Конго             61.3        13.0
# 74                             Кот-д'Ивуар             57.4        22.0
# 75                              Нидерланды             69.4        13.0
# 76           Российская Федерация - Москва             78.2        14.0
# 77                              Португалия             73.2        14.0
# 78                                 Намибия             70.0        12.0
#
#      days  cost  qa_index permit_raiting
# 56  180.0   0.8      12.0             77
# 57  180.0   1.9      12.0             86
# 58  180.0  20.3      13.0            173
# 59  179.0   2.3      14.0             57
# 60  178.0  12.6      10.0            140
# 61  177.0   7.8      10.0            131
# 62  175.0   0.9      14.0             ..
# 63  173.0   1.3      14.0             74
# 64  173.0   3.1       3.5            145
# 65  170.0   3.5      11.0            104
# 66  168.5   9.6      11.0            127
# 67  167.0   1.7      11.0             90
# 68  167.0   0.3       5.5            103
# 69  166.0   0.5      12.0             25
# 70  165.0   1.1      14.0             26
# 71  165.0   6.7      12.0            143
# 72  164.0   4.1      13.0             36
# 73  164.0   9.3       9.5            134
# 74  163.0   5.9      10.0            152
# 75  161.0   3.6      10.0             88
# 76  160.0   1.2      14.0             ..
# 77  160.0   1.2      11.0             60
# 78  160.0   2.0       8.5             84

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
near_russia.plot(kind="barh", x = 'country', y = 'days', figsize=(9,13), color='g');
# salary.plot(kind="barh", x = 'year', y = 'annual_salary');

# %%
procedures.query('days > 150 and days < 180').plot(kind="barh", x = 'country', y = ['procedures', 'cost'], color=['g', 'r'], figsize=(13, 15));

# %%
procedures = construction[construction['days'] != -9999.0].sort_values(by='procedures', ascending=False)
procedures.head(20)
# Out:
#                          country  building_permit  procedures   days  cost  \
# 81                   Таджикистан             60.8        26.0  157.0   3.0
# 178                      Либерия             28.9        25.0   87.0  24.1
# 53                      Танзания             57.9        24.0  184.0   5.4
# 17                       Румыния             58.4        24.0  260.0   2.0
# 112                  Южный Судан             50.5        23.0  131.0   8.5
# 12                         Ливан             53.7        22.0  276.0   7.7
# 71                   Пуэрто-Рико             59.6        22.0  165.0   6.7
# 74                   Кот-д'Ивуар             57.4        22.0  163.0   5.9
# 91                      Хорватия             57.8        22.0  146.0   9.2
# 45                       Венгрия             67.0        22.0  192.5   0.6
# 125                    Филиппины             70.0        22.0  120.0   2.3
# 11                       Молдова             56.2        21.0  278.0   3.7
# 87                         Бутан             68.9        21.0  150.0   0.9
# 24            Чешская Республика             56.2        21.0  246.0   0.2
# 63                        Египет             71.2        20.0  173.0   1.3
# 197                     Иордания             60.3        20.0   66.0  12.1
# 184            Бруней-Даруссалам             73.6        20.0   83.0   1.8
# 173                        Палау             63.1        20.0   90.0   3.2
# 84   Южно-Африканская Республика             68.3        20.0  155.0   1.9
# 0                       Камбоджа             44.6        20.0  652.0   3.0
#
#      qa_index permit_raiting
# 81       12.0            137
# 178       2.0            185
# 53       12.0            149
# 17       13.0            147
# 112       7.0            171
# 12       14.0            164
# 71       12.0            143
# 74       10.0            152
# 91       12.0            150
# 45       13.0            108
# 125      13.0             85
# 11       12.0            156
# 87       12.0             91
# 24        8.0            157
# 63       14.0             74
# 197      11.0            138
# 184      12.0             54
# 173       7.0            129
# 84       12.0             98
# 0         8.0            178

# %%
procedures.tail(20)
# Out:
#                  country  building_permit  procedures   days  cost  qa_index  \
# 72              Ирландия             76.6        10.0  164.0   4.1      13.0
# 50                Замбия             72.1        10.0  188.0   2.3      10.0
# 69               Вьетнам             79.3        10.0  166.0   0.5      12.0
# 60              Зимбабве             60.0        10.0  178.0  12.6      10.0
# 54                Лесото             52.9        10.0  183.0  11.3       5.0
# 4               Барбадос             56.6         9.0  377.0   0.2       6.5
# 206             Сингапур             87.9         9.0   35.5   3.3      13.0
# 203             Малайзия             89.0         9.0   53.0   1.3      13.0
# 114             Германия             78.2         9.0  126.0   1.1       9.5
# 172   Северная Македония             83.5         9.0   91.0   3.5      13.0
# 154           Черногория             76.1         9.0  102.0   4.9      10.0
# 35               Франция             74.3         9.0  213.0   3.9      13.0
# 179       Великобритания             80.3         9.0   86.0   1.1       9.0
# 192              Бахрейн             83.1         9.0   71.0   3.7      12.0
# 128               Швеция             78.0         8.0  117.0   1.9       9.0
# 194  САР, Гонконг, Китай             93.5         8.0   69.0   0.3      15.0
# 100         Лихтенштейн*             83.5         8.0  138.0   0.3      12.0
# 1                   Кипр             64.2         8.0  507.0   0.9      11.0
# 199                Дания             87.9         7.0   64.0   0.6      11.0
# 205   Маршалловы Острова             71.1         7.0   38.0   2.2       1.0
#
#     permit_raiting
# 72              36
# 50              67
# 69              25
# 60             140
# 54             165
# 4              153
# 206              5
# 203              2
# 114             30
# 172             15
# 154             40
# 35              52
# 179             23
# 192             17
# 128             31
# 194              1
# 100            NaN
# 1              125
# 199              4
# 205             76

# %%
procedure_plot = procedures.query('procedures > procedures.median()')
procedure_plot['procedures'].describe()
# Out:
# count    93.000000
# mean     18.290323
# std       2.277397
# min      16.000000
# 25%      17.000000
# 50%      18.000000
# 75%      19.000000
# max      26.000000
# Name: procedures, dtype: float64

# %%
procedures.query('procedures == procedures.median()')
# Out:
#                                   country  building_permit  procedures   days  \
# 39               Доминиканская Республика             70.7        15.0  206.0
# 105                               Эфиопия             59.7        15.0  136.0
# 117                                  Оман             75.2        15.0  125.0
# 193                               Бурунди             55.0        15.0   70.0
# 189                      Мексика - Мехико             67.8        15.0   76.0
# 120                               Вануату             54.6        15.0  123.0
# 174  Соединённые Штаты Америки - Нью-Йорк             80.1        15.0   89.0
# 97                                  Фиджи             67.8        15.0  141.0
# 146                                 Индия             78.7        15.0  106.0
# 26                                Боливия             60.0        15.0  235.0
# 165                                Руанда             70.6        15.0   97.0
# 123                          Буркина-Фасо             68.7        15.0  121.0
# 80                               Беларусь             75.2        15.0  158.0
# 22                  Бангладеш - Читтагонг             63.8        15.0  247.0
# 186                               Мексика             68.8        15.0   82.0
# 90                                Гренада             62.5        15.0  146.0
# 147                               Нигерия             73.6        15.0  105.0
# 92                             Сан-Марино             68.9        15.0  145.5
#
#      cost  qa_index permit_raiting
# 39    2.4      13.0             80
# 105  12.6      11.0            142
# 117   0.8      11.0             47
# 193  12.1       5.0            161
# 189  10.9      12.0             ..
# 120   9.4       5.0            163
# 174   0.3      12.0             ..
# 97    0.5       7.0            102
# 146   4.0      14.5             27
# 26    1.3       7.0            139
# 165  11.4      15.0             81
# 123   7.6      12.0             95
# 80    1.6      13.0             48
# 22    1.5      10.0             ..
# 186   9.5      11.7             93
# 90    1.8       5.0            130
# 147   4.0      11.8             55
# 92    7.3      13.0             92

# %%
procedures.query('procedures == procedures.max()')
# Out:
#         country  building_permit  procedures   days  cost  qa_index  \
# 81  Таджикистан             60.8        26.0  157.0   3.0      12.0
#
#    permit_raiting
# 81            137

# %%
procedures.query('procedures == procedures.min()')
# Out:
#                 country  building_permit  procedures  days  cost  qa_index  \
# 199               Дания             87.9         7.0  64.0   0.6      11.0
# 205  Маршалловы Острова             71.1         7.0  38.0   2.2       1.0
#
#     permit_raiting
# 199              4
# 205             76

# %%
procedures.query('procedures > 16 and procedures < 20').plot(kind="barh", x = 'country', y = 'days', color='g', figsize=(6, 19));

# %%
# plotting
# plt.plot(population['population_total'], pop_total, label='Общая численность населения')
plt.figure(figsize=(27, 7))
plt.plot(procedure_plot['country'], procedure_plot['procedures'], label='Число процедур для получения разрешения на строительство')
plt.plot(procedure_plot['country'], procedure_plot['days'], label='Количество дней на получение разрешения на строительство')
plt.plot(procedure_plot['country'], procedure_plot['cost'], label='Затраты на получения разрешения на строительство, млн руб')

# plot detailes
plt.legend(loc='upper left')
plt.xlabel('Страна')
# plt.ylabel('Численность населения России, млн чел.')
plt.ticklabel_format(style='plain', axis='y')
plt.title('Строительная отрасль');

# %%
procedures.query('country == "Российская Федерация" or country == "Российская Федерация - Москва" or country == "Российская Федерация - Санкт-Петербург"')
# Out:
#                                    country  building_permit  procedures  \
# 76           Российская Федерация - Москва             78.2        14.0
# 70                    Российская Федерация             78.9        13.0
# 62  Российская Федерация - Санкт-Петербург             80.5        11.0
#
#      days  cost  qa_index permit_raiting
# 76  160.0   1.2      14.0             ..
# 70  165.0   1.1      14.0             26
# 62  175.0   0.9      14.0             ..

# %% [markdown]
# ## Жилищный фонд по субъектам Россиийской Федерации

# %%
square_per_person = pd.read_excel('/Users/yuliabezginova/PycharmProjects/real_estate_2022/Jil_fond.xls')

# %%
square_per_person
# Out:
#     Содержание:                                         Unnamed: 1
# 0           NaN                                                NaN
# 1           1.0  Общая площадь жилых помещений по состоянию на ...
# 2           2.0  Общая площадь жилых помещений по формам собств...
# 3           3.0  Общая площадь жилых помещений по материалам ст...
# 4           4.0  Прибыло общей площади жилищного фонда за 2021 год
# 5           5.0   Выбыло общей площади жилищного фонда за 2021 год
# 6           6.0  Общая площадь жилых помещений по состоянию на ...
# 7           7.0  Общая площадь жилых помещений по формам собств...
# 8           8.0  Общая площадь жилых помещений по материалам ст...
# 9           9.0  Прибыло общей площади жилищного фонда за 2020 год
# 10         10.0   Выбыло общей площади жилищного фонда за 2020 год
# 11          NaN                                                NaN
# 12          NaN                                                NaN
# 13          NaN                              Обновлено: 20.06.2022
